# %% [markdown]
# **Extracting features of 2018 movies from Wikipedia**

# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df1
# Out:
#             Opening  Opening.1                                Title  \
# 0     J A N U A R Y          5              Insidious: The Last Key
# 1     J A N U A R Y          5                     The Strange Ones
# 2     J A N U A R Y         12                         The Commuter
# 3     J A N U A R Y         12                           Proud Mary
# 4     J A N U A R Y         12                     Acts of Violence
# 5     J A N U A R Y         12                           Freak Show
# 6     J A N U A R Y         12                             Humor Me
# 7     J A N U A R Y         19                            12 Strong
# 8     J A N U A R Y         19                       Den of Thieves
# 9     J A N U A R Y         19                      Forever My Girl
# 10    J A N U A R Y         25                 Thane of East County
# 11    J A N U A R Y         26          Maze Runner: The Death Cure
# 12    J A N U A R Y         26                      Please Stand By
# 13  F E B R U A R Y          2                           Winchester
# 14  F E B R U A R Y          2                    A Fantastic Woman
# 15  F E B R U A R Y          2                                Armed
# 16  F E B R U A R Y          4              The Cloverfield Paradox
# 17  F E B R U A R Y          6                           Bad Apples
# 18  F E B R U A R Y          9                         Peter Rabbit
# 19  F E B R U A R Y          9                              Pad Man
# 20  F E B R U A R Y          9                   Fifty Shades Freed
# 21  F E B R U A R Y          9                   The 15:17 to Paris
# 22  F E B R U A R Y          9                           Permission
# 23  F E B R U A R Y          9                         Golden Exits
# 24  F E B R U A R Y         16                        Black Panther
# 25  F E B R U A R Y         16                            Nostalgia
# 26  F E B R U A R Y         16                               Samson
# 27  F E B R U A R Y         23                           Game Night
# 28  F E B R U A R Y         23                         Annihilation
# 29  F E B R U A R Y         23                            Every Day
# 30  F E B R U A R Y         23                            The Cured
# 31        M A R C H          2                          Red Sparrow
# 32        M A R C H          2                           Death Wish
# 33        M A R C H          2         The Vanishing of Sidney Hall
# 34        M A R C H          2                             Pickings
# 35        M A R C H          9                    A Wrinkle in Time
# 36        M A R C H          9                               Gringo
# 37        M A R C H          9                        Thoroughbreds
# 38        M A R C H          9         The Strangers: Prey at Night
# 39        M A R C H          9                  The Hurricane Heist
# 40        M A R C H         16                          Tomb Raider
# 41        M A R C H         16                          Love, Simon
# 42        M A R C H         16                   I Can Only Imagine
# 43        M A R C H         16                              Entebbe
# 44        M A R C H         16                             Furlough
# 45        M A R C H         16                                Josie
# 46        M A R C H         16                               Flower
# 47        M A R C H         23                 Pacific Rim Uprising
# 48        M A R C H         23                         Isle of Dogs
# 49        M A R C H         23                      Sherlock Gnomes
# 50        M A R C H         23                               Unsane
# 51        M A R C H         23              Paul, Apostle of Christ
# 52        M A R C H         23                       Final Portrait
# 53        M A R C H         23                         Midnight Sun
# 54        M A R C H         29                     Ready Player One
# 55        M A R C H         30                             Acrimony
# 56        M A R C H         30  God's Not Dead: A Light in Darkness
# 57        M A R C H         30                               Gemini
# 58        M A R C H         30                  The Last Movie Star
#
#                                    Production company  \
# 0   Universal Pictures / Blumhouse Productions / S...
# 1                              Vertical Entertainment
# 2       Lionsgate / StudioCanal / The Picture Company
# 3                                         Screen Gems
# 4                                  Lionsgate Premiere
# 5                                           IFC Films
# 6                     Shout! Factory / Shout! Studios
# 7   Warner Bros. Pictures / Alcon Entertainment / ...
# 8                                   STX Entertainment
# 9                                Roadside Attractions
# 10     Folk Process Films / Summer Hill Entertainment
# 11                                   20th Century Fox
# 12                                  Magnolia Pictures
# 13                              Lionsgate / CBS Films
# 14                             Sony Pictures Classics
# 15                                      GVN Releasing
# 16           Paramount Pictures / Netflix / Bad Robot
# 17                             Uncork'd Entertainment
# 18  Columbia Pictures / Sony Pictures Animation / ...
# 19           Columbia Pictures / KriArj Entertainment
# 20   Universal Pictures / Michael De Luca Productions
# 21  Warner Bros. Pictures / Village Roadshow Pictu...
# 22                            Good Dead Entertainment
# 23             Vertical Entertainment / Stage 6 Films
# 24                                     Marvel Studios
# 25                                    Bleecker Street
# 26                                          Pure Flix
# 27  Warner Bros. Pictures / New Line Cinema / Acce...
# 28    Paramount Pictures / Skydance Media / DNA Films
# 29                                     Orion Pictures
# 30                                          IFC Films
# 31  20th Century Fox / TSG Entertainment / Chernin...
# 32                                Metro-Goldwyn-Mayer
# 33                                                A24
# 34                        Digital Magic Entertainment
# 35                               Walt Disney Pictures
# 36                 Amazon Studios / STX Entertainment
# 37                                     Focus Features
# 38                            Aviron Pictures / Rogue
# 39                              Entertainment Studios
# 40  Warner Bros. Pictures / GK Films / Metro-Goldw...
# 41  20th Century Fox / Fox 2000 Pictures / TSG Ent...
# 42                   Roadside Attractions / Lionsgate
# 43  Focus Features / StudioCanal / Participant Med...
# 44                                          IFC Films
# 45                                 Screen Media Films
# 46                                        The Orchard
# 47            Universal Pictures / Legendary Pictures
# 48       Fox Searchlight Pictures / Indian Paintbrush
# 49  Paramount Pictures / Paramount Animation / Met...
# 50              Bleecker Street / Regency Enterprises
# 51                                       Affirm Films
# 52                             Sony Pictures Classics
# 53                          Global Road Entertainment
# 54  Warner Bros. Pictures / Village Roadshow Pictu...
# 55                      Lionsgate / Tyler Perry Films
# 56                                          Pure Flix
# 57                                               Neon
# 58                                                A24
#
#                                         Cast and crew  Ref.
# 0   Adam Robitel (director); Leigh Whannell (scree...   [2]
# 1   Christopher Radcliff (director/screenplay); La...   [3]
# 2   Jaume Collet-Serra (director); Byron Willinger...   [4]
# 3   Babak Najafi (director); John S. Newman, Chris...   [5]
# 4   Brett Donowho (director); Nicolas Aaron Mezzan...   [6]
# 5   Trudie Styler (director); Patrick J. Clifton, ...   [7]
# 6   Sam Hoffman (director/screenplay); Jemaine Cle...   [8]
# 7   Nicolai Fuglsig (director); Ted Tally, Peter C...   [9]
# 8   Christian Gudegast (director/screenplay); Gera...  [10]
# 9   Bethany Ashton Wolf (director/screenplay); Ale...  [11]
# 10  Jesse Keller (director/screenplay); Carr Caven...  [12]
# 11  Wes Ball (director); T. S. Nowlin (screenplay)...  [13]
# 12  Ben Lewin (director); Michael Golamco (screenp...  [14]
# 13  The Spierig Brothers (director/screenplay); To...  [15]
# 14  Sebastián Lelio (director/screenplay); Gonzalo...  [16]
# 15  Mario Van Peebles (director/screenplay); Mario...  [17]
# 16  Julius Onah (director); Oren Uziel (screenplay...  [18]
# 17  Bryan Coyne (director/screenplay); Brea Grant,...  [19]
# 18  Will Gluck (director/screenplay); Rob Lieber (...  [20]
# 19  R. Balki (director/screenplay); Swanand Kirkir...   NaN
# 20  James Foley (director); Niall Leonard (screenp...  [21]
# 21  Clint Eastwood (director); Dorothy Blyskal (sc...  [22]
# 22  Brian Crano (director/screenplay); Rebecca Hal...  [23]
# 23  Alex Ross Perry (director/screenplay); Emily B...  [24]
# 24  Ryan Coogler (director/​screenplay); Joe Rober...  [25]
# 25  Mark Pellington (director/screenplay); Alex Ro...  [26]
# 26  Bruce Macdonald (director); Jason Baumgardner,...  [27]
# 27  John Francis Daley, Jonathan Goldstein (direct...  [28]
# 28  Alex Garland (director/screenplay); Natalie Po...  [29]
# 29  Michael Sucsy (director); Jesse Andrews (scree...  [30]
# 30  David Freyne (director/screenplay); Ellen Page...  [31]
# 31  Francis Lawrence (director); Justin Haythe (sc...  [32]
# 32  Eli Roth (director); Joe Carnahan (screenplay)...  [33]
# 33  Shawn Christensen (director/screenplay); Jason...  [34]
# 34  Usher Morgan (director/screenplay); Elyse Pric...  [35]
# 35  Ava DuVernay (director); Jennifer Lee, Jeff St...  [36]
# 36  Nash Edgerton (director); Matthew Stone, Antho...  [37]
# 37  Cory Finley (director/screenplay); Olivia Cook...  [38]
# 38  Johannes Roberts (director); Bryan Bertino, Be...  [39]
# 39  Rob Cohen (director); Scott Windhauser, Jeff D...  [40]
# 40  Roar Uthaug (director); Geneva Robertson-Dwore...  [41]
# 41  Greg Berlanti (director); Isaac Aptaker, Eliza...  [42]
# 42  Erwin brothers (directors); Jon Erwin, Brent M...  [43]
# 43  José Padilha (director); Gregory Burke (screen...  [44]
# 44  Laurie Collyer (director); Barry Strugatz (scr...  [45]
# 45  Eric England (director), Anthony Ragnone II (s...  [46]
# 46  Max Winkler (director/screenplay); Alex McAula...  [47]
# 47  Steven S. DeKnight (director/screenplay); Emil...  [48]
# 48  Wes Anderson (director/screenplay); Bryan Cran...  [49]
# 49  John Stevenson (director); Ben Zazove (screenp...  [50]
# 50  Steven Soderbergh (director); Jonathan Bernste...  [51]
# 51  Andrew Hyatt (director/screenplay); Jim Caviez...  [52]
# 52  Stanley Tucci (director/screenplay); Geoffrey ...  [53]
# 53  Scott Speer (director); Eric Kirsten (screenpl...  [54]
# 54  Steven Spielberg (director); Zak Penn, Ernest ...  [55]
# 55  Tyler Perry (director/screenplay); Taraji P. H...  [56]
# 56  Michael Mason (director/screenplay); David A. ...  [57]
# 57  Aaron Katz (director/screenplay); Lola Kirke, ...  [58]
# 58  Adam Rifkin (director/screenplay); Burt Reynol...  [59]

# %%
df2
# Out:
#       Opening  Opening.1                            Title  \
# 0   A P R I L          6                    A Quiet Place
# 1   A P R I L          6                         Blockers
# 2   A P R I L          6       You Were Never Really Here
# 3   A P R I L          6                   Chappaquiddick
# 4   A P R I L          6               The Miracle Season
# 5   A P R I L          8                          Paterno
# 6   A P R I L         11                           Beirut
# 7   A P R I L         13                          Rampage
# 8   A P R I L         13                    Truth or Dare
# 9   A P R I L         13                        The Rider
# 10  A P R I L         13    Sgt. Stubby: An American Hero
# 11  A P R I L         13                        Sign Gene
# 12  A P R I L         20                    I Feel Pretty
# 13  A P R I L         20                 Super Troopers 2
# 14  A P R I L         20                          Traffik
# 15  A P R I L         20            The House of Tomorrow
# 16  A P R I L         27           Avengers: Infinity War
# 17  A P R I L         27                     Disobedience
# 18  A P R I L         27       Backstabbing for Beginners
# 19  A P R I L         27                            Kings
# 20      M A Y          4                        Overboard
# 21      M A Y          4                            Tully
# 22      M A Y          4                    Bad Samaritan
# 23      M A Y          4                      The Cleanse
# 24      M A Y         11                Life of the Party
# 25      M A Y         11                      Breaking In
# 26      M A Y         11                      The Seagull
# 27      M A Y         11                         Terminal
# 28      M A Y         18                       Deadpool 2
# 29      M A Y         18                        Book Club
# 30      M A Y         18                   First Reformed
# 31      M A Y         18                        Show Dogs
# 32      M A Y         19                   Fahrenheit 451
# 33      M A Y         25          Solo: A Star Wars Story
# 34      M A Y         25  How to Talk to Girls at Parties
# 35      M A Y         25                      In Darkness
# 36      M A Y         25                     Future World
# 37      M A Y         26                         The Tale
# 38    J U N E          1                     Action Point
# 39    J U N E          1                           Adrift
# 40    J U N E          1                          Upgrade
# 41    J U N E          1                 American Animals
# 42    J U N E          1                   Social Animals
# 43    J U N E          8                        Ocean's 8
# 44    J U N E          8        Won't You Be My Neighbor?
# 45    J U N E          8                       Hereditary
# 46    J U N E          8                    Hotel Artemis
# 47    J U N E         13                         Superfly
# 48    J U N E         15                    Incredibles 2
# 49    J U N E         15                              Tag
# 50    J U N E         15                            Gotti
# 51    J U N E         22   Jurassic World: Fallen Kingdom
# 52    J U N E         22                       Boundaries
# 53    J U N E         22                           Damsel
# 54    J U N E         28                    The Domestics
# 55    J U N E         29      Sicario: Day of the Soldado
# 56    J U N E         29                   Leave No Trace
# 57    J U N E         29           Love All You Have Left
# 58    J U N E         29                       Uncle Drew
# 59    J U N E         29                Woman Walks Ahead
#
#                                    Production company  \
# 0   Paramount Pictures / Platinum Dunes / Sunday N...
# 1   Universal Pictures / Good Universe / Point Gre...
# 2                                      Amazon Studios
# 3                               Entertainment Studios
# 4                                    LD Entertainment
# 5   HBO Films / Levinson/Fontana / Sony Pictures T...
# 6                                     Bleecker Street
# 7   Warner Bros. Pictures / New Line Cinema / Seve...
# 8          Universal Pictures / Blumhouse Productions
# 9                              Sony Pictures Classics
# 10         Fun Academy Motion Pictures / Mikros Image
# 11                                  Pluin Productions
# 12                                  STX Entertainment
# 13                           Fox Searchlight Pictures
# 14             Summit Entertainment / Codeblack Films
# 15                                     Shout! Studios
# 16                                     Marvel Studios
# 17                                    Bleecker Street
# 18                                                A24
# 19                                        The Orchard
# 20  Metro-Goldwyn-Mayer / Lionsgate / Pantelion Films
# 21                      Focus Features / Bron Studios
# 22                             Electric Entertainment
# 23                             Vertical Entertainment
# 24            Warner Bros. Pictures / New Line Cinema
# 25                                 Universal Pictures
# 26                             Sony Pictures Classics
# 27                                         RLJE Films
# 28  20th Century Fox / Marvel Entertainment / TSG ...
# 29                                 Paramount Pictures
# 30                                                A24
# 31                          Global Road Entertainment
# 32                        HBO Films / Outlier Society
# 33                                          Lucasfilm
# 34                                                A24
# 35                             Vertical Entertainment
# 36                                 Lionsgate Premiere
# 37  HBO Films / Gamechanger Films / Fork Films / O...
# 38                                 Paramount Pictures
# 39                                  STX Entertainment
# 40                                            BH Tilt
# 41                   The Orchard / MoviePass Ventures
# 42                             Vertical Entertainment
# 43  Warner Bros. Pictures / Village Roadshow Pictures
# 44                                     Focus Features
# 45                                                A24
# 46                          Global Road Entertainment
# 47                Columbia Pictures / Silver Pictures
# 48     Walt Disney Pictures / Pixar Animation Studios
# 49            Warner Bros. Pictures / New Line Cinema
# 50                             Vertical Entertainment
# 51  Universal Pictures / Amblin Entertainment / Le...
# 52                             Sony Pictures Classics
# 53                                  Magnolia Pictures
# 54                                     Orion Classics
# 55  Columbia Pictures / Black Label Media / Thunde...
# 56                                    Bleecker Street
# 57                   Dongo Productions / Indie Rights
# 58                               Summit Entertainment
# 59                                                A24
#
#                                         Cast and crew   Ref.
# 0   John Krasinski (director/screenplay); Bryan Wo...   [60]
# 1   Kay Cannon (director); Brian Kehoe, Jim Kehoe ...   [61]
# 2   Lynne Ramsay (director/screenplay); Joaquin Ph...   [62]
# 3   John Curran (director); Taylor Allen, Andrew L...   [63]
# 4   Sean McNamara (director); David Aaron Cohen, E...   [64]
# 5   Barry Levinson (director); Debora Cahn, John C...    NaN
# 6   Brad Anderson (director); Tony Gilroy (screenp...   [26]
# 7   Brad Peyton (director); Ryan Engle, Carlton Cu...   [65]
# 8   Jeff Wadlow (director/screenplay); Michael Rei...   [66]
# 9   Chloé Zhao (director/screenplay); Brady Jandre...   [67]
# 10  Richard Lanni (director/screenplay); Mike Stok...   [68]
# 11  Emilio Insolera (director/screenplay); Emilio ...   [69]
# 12  Abby Kohn, Marc Silverstein (director/screenpl...   [70]
# 13  Jay Chandrasekhar (director); Broken Lizard (s...   [71]
# 14  Deon Taylor (director/screenplay); Paula Patto...   [72]
# 15  Peter Livolsi (director/screenplay); Ellen Bur...   [73]
# 16  Russo brothers (directors); Christopher Markus...   [74]
# 17  Sebastián Lelio (director/screenplay); Rebecca...   [26]
# 18  Per Fly (director/screenplay); Daniel Pyne (sc...   [75]
# 19  Deniz Gamze Ergüven (director/screenplay); Hal...   [76]
# 20  Rob Greenberg (director); Bob Fisher, Leslie D...   [72]
# 21  Jason Reitman (director); Diablo Cody (screenp...   [77]
# 22  Dean Devlin (director); Brandon Boyce (screenp...   [78]
# 23  Bobby Miller (director/screenplay); Johnny Gal...   [79]
# 24  Ben Falcone (director/screenplay); Melissa McC...   [80]
# 25  James McTeigue (director); Ryan Engle (screenp...   [81]
# 26  Michael Mayer (director); Stephen Karam (scree...   [82]
# 27  Vaughn Stein (director/screenplay); Margot Rob...   [83]
# 28  David Leitch (director); Rhett Reese, Paul Wer...   [84]
# 29  Bill Holderman (director/screenplay); Erin Sim...   [85]
# 30  Paul Schrader (director/screenplay); Ethan Haw...   [86]
# 31  Raja Gosnell (director); Max Botkin, Marc Hyma...   [87]
# 32  Ramin Bahrani (director/screenplay); Amir Nade...    NaN
# 33  Ron Howard (director); Jonathan Kasdan, Lawren...   [88]
# 34  John Cameron Mitchell (director/screenplay); P...   [89]
# 35  Anthony Byrne (director/screenplay); Natalie D...   [90]
# 36  James Franco (director); Bruce Thierry Cheung ...   [91]
# 37  Jennifer Fox (director/screenplay); Laura Dern...    NaN
# 38  Tim Kirkby (director); John Altschuler, Dave K...   [92]
# 39  Baltasar Kormákur (director); Aaron Kandell, J...   [93]
# 40  Leigh Whannell (director/screenplay); Logan Ma...   [94]
# 41  Bart Layton (director/screenplay); Evan Peters...   [95]
# 42  Theresa Bennett (director/screenplay); Noël We...   [96]
# 43  Gary Ross (director/screenplay); Olivia Milch ...   [97]
# 44  Morgan Neville (director); Fred Rogers, Franço...   [98]
# 45  Ari Aster (director/screenplay); Toni Collette...   [99]
# 46  Drew Pearce (director/screenplay); Jodie Foste...  [100]
# 47  Director X (director); Alex Tse (screenplay); ...  [101]
# 48  Brad Bird (director/screenplay); Craig T. Nels...  [102]
# 49  Jeff Tomsic (director); Rob McKittrick, Mark S...  [103]
# 50  Kevin Connolly (director); Lem Dobbs, Leo Ross...  [104]
# 51  J. A. Bayona (director); Derek Connolly, Colin...  [105]
# 52  Shana Feste (director/screenplay); Vera Farmig...  [106]
# 53  David Zellner, Nathan Zellner (directors/scree...  [107]
# 54  Mike P. Nelson (director/screenplay); Tyler Ho...  [108]
# 55  Stefano Sollima (director); Taylor Sheridan (s...  [109]
# 56  Debra Granik (director/screenplay); Anne Rosel...  [110]
# 57  Matt Sivertson (director/screenplay); Caroline...  [111]
# 58  Charles Stone III (director); Jay Longino (scr...  [112]
# 59  Susanna White (director); Steven Knight (scree...  [113]

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True, sort=False)
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 244  D E C E M B E R         21               Second Act
# 245  D E C E M B E R         25          Holmes & Watson
# 246  D E C E M B E R         25                     Vice
# 247  D E C E M B E R         25      On the Basis of Sex
# 248  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 244                                  STX Entertainment
# 245  Columbia Pictures / Gary Sanchez Productions /...
# 246          Annapurna Pictures / Plan B Entertainment
# 247                                     Focus Features
# 248                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 244  Peter Segal (director); Justin Zackham, Elaine...  [238]
# 245  Etan Cohen (director/screenplay); Will Ferrell...  [142]
# 246  Adam McKay (director/screenplay); Christian Ba...  [117]
# 247  Mimi Leder (director); Daniel Stiepleman (scre...  [207]
# 248  Karyn Kusama (director); Phil Hay, Matt Manfre...  [239]
#
# [249 rows x 6 columns]

# %% [markdown]
# As it is observed in the above table, we do not have the **genre** column so we will get the genre data from IMDb. You will need to create an API key in order to access the API key.

# %%
pip install tmdbv3api
# Out:
# Collecting tmdbv3apiNote: you may need to restart the kernel to use updated packages.
#
#   Downloading tmdbv3api-1.9.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests in c:\users\asus\appdata\roaming\python\python312\site-packages (from tmdbv3api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\appdata\roaming\python\python312\site-packages (from requests->tmdbv3api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\roaming\python\python312\site-packages (from requests->tmdbv3api) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from requests->tmdbv3api) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\roaming\python\python312\site-packages (from requests->tmdbv3api) (2024.8.30)
# Downloading tmdbv3api-1.9.0-py3-none-any.whl (25 kB)
# Installing collected packages: tmdbv3api
# Successfully installed tmdbv3api-1.9.0

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '5eeb5c4e26bc30cdeea9e1ce4f88edfa'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x): #pass in the title of the movies
    genres = []
    result = tmdb_movie.search(x) #the title will be searched in the tmdb_movie
    movie_id = result[0].id #we will match the "id" with the "title"
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key)) #we will get the result from the IMDb data
    data_json = response.json() #we will then convert it to a json file
    if data_json['genres']: #in the json file we will only need to extract the "genre"
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name']) #we will then add the "genre" to the empty genre list we created above
        return genre_str.join(genres)
    else:
        np.NaN # we will return the results but if we don't find anything we will consider it as a missing value

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 244  D E C E M B E R         21               Second Act
# 245  D E C E M B E R         25          Holmes & Watson
# 246  D E C E M B E R         25                     Vice
# 247  D E C E M B E R         25      On the Basis of Sex
# 248  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 244                                  STX Entertainment
# 245  Columbia Pictures / Gary Sanchez Productions /...
# 246          Annapurna Pictures / Plan B Entertainment
# 247                                     Focus Features
# 248                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 244  Peter Segal (director); Justin Zackham, Elaine...  [238]
# 245  Etan Cohen (director/screenplay); Will Ferrell...  [142]
# 246  Adam McKay (director/screenplay); Christian Ba...  [117]
# 247  Mimi Leder (director); Daniel Stiepleman (scre...  [207]
# 248  Karyn Kusama (director); Phil Hay, Matt Manfre...  [239]
#
#                       genres
# 0            Horror Thriller
# 1             Thriller Drama
# 2    Action Thriller Mystery
# 3      Thriller Action Crime
# 4      Action Crime Thriller
# ..                       ...
# 244           Romance Comedy
# 245     Comedy Mystery Crime
# 246             Comedy Drama
# 247            Drama History
# 248          Horror Thriller
#
# [249 rows x 7 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 244               Second Act
# 245          Holmes & Watson
# 246                     Vice
# 247      On the Basis of Sex
# 248                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 244  Peter Segal (director); Justin Zackham, Elaine...
# 245  Etan Cohen (director/screenplay); Will Ferrell...
# 246  Adam McKay (director/screenplay); Christian Ba...
# 247  Mimi Leder (director); Daniel Stiepleman (scre...
# 248  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                       genres
# 0            Horror Thriller
# 1             Thriller Drama
# 2    Action Thriller Mystery
# 3      Thriller Action Crime
# 4      Action Crime Thriller
# ..                       ...
# 244           Romance Comedy
# 245     Comedy Mystery Crime
# 246             Comedy Drama
# 247            Drama History
# 248          Horror Thriller
#
# [249 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x: #we are getting "director"
        return x.split(" (director)")[0]
    elif " (directors)" in x: #we are getting "directors" with "s"
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0] #we are getting "directors/screenplay"

# %%
#let's apply the above function on the "Cast and crew" column
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_31064\1280007071.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 244               Second Act
# 245          Holmes & Watson
# 246                     Vice
# 247      On the Basis of Sex
# 248                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 244  Peter Segal (director); Justin Zackham, Elaine...
# 245  Etan Cohen (director/screenplay); Will Ferrell...
# 246  Adam McKay (director/screenplay); Christian Ba...
# 247  Mimi Leder (director); Daniel Stiepleman (scre...
# 248  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                       genres  \
# 0            Horror Thriller
# 1             Thriller Drama
# 2    Action Thriller Mystery
# 3      Thriller Action Crime
# 4      Action Crime Thriller
# ..                       ...
# 244           Romance Comedy
# 245     Comedy Mystery Crime
# 246             Comedy Drama
# 247            Drama History
# 248          Horror Thriller
#
#                                          director_name
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 244                                        Peter Segal
# 245                                         Etan Cohen
# 246                                         Adam McKay
# 247                                         Mimi Leder
# 248                                       Karyn Kusama
#
# [249 rows x 4 columns]

# %% [markdown]
# **ACTOR 1**

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_31064\2274966287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %% [markdown]
# **ACTOR 2**

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_31064\3672495884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %% [markdown]
# **Actor 3**

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 244               Second Act
# 245          Holmes & Watson
# 246                     Vice
# 247      On the Basis of Sex
# 248                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 244  Peter Segal (director); Justin Zackham, Elaine...
# 245  Etan Cohen (director/screenplay); Will Ferrell...
# 246  Adam McKay (director/screenplay); Christian Ba...
# 247  Mimi Leder (director); Daniel Stiepleman (scre...
# 248  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                       genres  \
# 0            Horror Thriller
# 1             Thriller Drama
# 2    Action Thriller Mystery
# 3      Thriller Action Crime
# 4      Action Crime Thriller
# ..                       ...
# 244           Romance Comedy
# 245     Comedy Mystery Crime
# 246             Comedy Drama
# 247            Drama History
# 248          Horror Thriller
#
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 244                                        Peter Segal
# 245                                         Etan Cohen
# 246                                         Adam McKay
# 247                                         Mimi Leder
# 248                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 244                              Jennifer Lopez             Leah Remini
# 245                                Will Ferrell          John C. Reilly
# 246                              Christian Bale               Amy Adams
# 247                              Felicity Jones            Armie Hammer
# 248                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name
# 0     Leigh Whannell
# 1      Emily Althaus
# 2     Patrick Wilson
# 3        Billy Brown
# 4      Shawn Ashmore
# ..               ...
# 244  Vanessa Hudgens
# 245     Rebecca Hall
# 246     Steve Carell
# 247   Justin Theroux
# 248     Toby Kebbell
#
# [249 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 244                                        Peter Segal
# 245                                         Etan Cohen
# 246                                         Adam McKay
# 247                                         Mimi Leder
# 248                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 244                              Jennifer Lopez             Leah Remini
# 245                                Will Ferrell          John C. Reilly
# 246                              Christian Bale               Amy Adams
# 247                              Felicity Jones            Armie Hammer
# 248                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name                   genres              movie_title
# 0     Leigh Whannell          Horror Thriller  Insidious: The Last Key
# 1      Emily Althaus           Thriller Drama         The Strange Ones
# 2     Patrick Wilson  Action Thriller Mystery             The Commuter
# 3        Billy Brown    Thriller Action Crime               Proud Mary
# 4      Shawn Ashmore    Action Crime Thriller         Acts of Violence
# ..               ...                      ...                      ...
# 244  Vanessa Hudgens           Romance Comedy               Second Act
# 245     Rebecca Hall     Comedy Mystery Crime          Holmes & Watson
# 246     Steve Carell             Comedy Drama                     Vice
# 247   Justin Theroux            Drama History      On the Basis of Sex
# 248     Toby Kebbell          Horror Thriller                Destroyer
#
# [249 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 244                                        Peter Segal
# 245                                         Etan Cohen
# 246                                         Adam McKay
# 247                                         Mimi Leder
# 248                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 244                              Jennifer Lopez             Leah Remini
# 245                                Will Ferrell          John C. Reilly
# 246                              Christian Bale               Amy Adams
# 247                              Felicity Jones            Armie Hammer
# 248                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name                   genres              movie_title  \
# 0     Leigh Whannell          Horror Thriller  insidious: the last key
# 1      Emily Althaus           Thriller Drama         the strange ones
# 2     Patrick Wilson  Action Thriller Mystery             the commuter
# 3        Billy Brown    Thriller Action Crime               proud mary
# 4      Shawn Ashmore    Action Crime Thriller         acts of violence
# ..               ...                      ...                      ...
# 244  Vanessa Hudgens           Romance Comedy               second act
# 245     Rebecca Hall     Comedy Mystery Crime          holmes & watson
# 246     Steve Carell             Comedy Drama                     vice
# 247   Justin Theroux            Drama History      on the basis of sex
# 248     Toby Kebbell          Horror Thriller                destroyer
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3    Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 244  Jennifer Lopez Leah Remini Vanessa Hudgens Pet...
# 245  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 246  Christian Bale Amy Adams Steve Carell Adam McK...
# 247  Felicity Jones Armie Hammer Justin Theroux Mim...
# 248  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
#
# [249 rows x 7 columns]

# %% [markdown]
# **Extracting features of 2019 movies from Wikipedia**

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True, sort=False)

# %%
df
# Out:
#              Opening Opening.1              Title  \
# 0      J A N U A R Y         4        Escape Room
# 1      J A N U A R Y         4         Rust Creek
# 2      J A N U A R Y         4   American Hangman
# 3      J A N U A R Y        11   A Dog's Way Home
# 4      J A N U A R Y        11         The Upside
# ..               ...       ...                ...
# 245  D E C E M B E R        25  Spies in Disguise
# 246  D E C E M B E R        25       Little Women
# 247  D E C E M B E R        25               1917
# 248  D E C E M B E R        25         Just Mercy
# 249  D E C E M B E R        27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 245  20th Century Fox Animation / Blue Sky Studios ...
# 246            Columbia Pictures / Regency Enterprises
# 247           Universal Pictures / DreamWorks Pictures
# 248                Warner Bros. Pictures / Participant
# 249                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 245  Nick Bruno, Troy Quane (directors); Brad Copel...  [133]
# 246  Greta Gerwig (director/screenplay); Saoirse Ro...  [226]
# 247  Sam Mendes (director/screenplay); Krysty Wilso...  [227]
# 248  Destin Daniel Cretton (director/screenplay), A...  [228]
# 249  Chinonye Chukwu (director/screenplay); Alfre W...  [229]
#
# [250 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 245  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 246       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 247               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 248         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 249           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# 0                     Horror Thriller Mystery
# 1                 Thriller Drama Action Crime
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 245  Animation Action Adventure Comedy Family
# 246                      Romance Drama Family
# 247                War History Thriller Drama
# 248                       Drama Crime History
# 249                                     Drama
#
# [250 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_31064\203239715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_31064\1562076556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_31064\3736213850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 245  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 246            Greta Gerwig        Saoirse Ronan           Emma Watson
# 247              Sam Mendes        George MacKay  Dean-Charles Chapman
# 248   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 249         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# 0    Deborah Ann Woll                   Horror Thriller Mystery
# 1        Sean O'Bryan               Thriller Drama Action Crime
# 2       Oliver Dennis                                  Thriller
# 3     Alexandra Shipp                    Drama Adventure Family
# 4       Nicole Kidman                              Comedy Drama
# ..                ...                                       ...
# 245     Rashida Jones  Animation Action Adventure Comedy Family
# 246     Florence Pugh                      Romance Drama Family
# 247       Mark Strong                War History Thriller Drama
# 248       Brie Larson                       Drama Crime History
# 249       Aldis Hodge                                     Drama
#
#            movie_title                                               comb
# 0          escape room  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1           rust creek  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2     american hangman  Donald Sutherland Vincent Kartheiser Oliver De...
# 3     a dog's way home  Bryce Dallas Howard Edward James Olmos Alexand...
# 4           the upside  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                 ...                                                ...
# 245  spies in disguise  Will Smith Tom Holland Rashida Jones Nick Brun...
# 246       little women  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 247               1917  George MacKay Dean-Charles Chapman Mark Strong...
# 248         just mercy  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 249           clemency  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [250 rows x 7 columns]

# %%
my_df = pd.concat([new_df18, new_df19], ignore_index=True, sort=False)
my_df
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 494                             Nick Bruno, Troy Quane
# 495                                       Greta Gerwig
# 496                                         Sam Mendes
# 497                              Destin Daniel Cretton
# 498                                    Chinonye Chukwu
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 494                                  Will Smith             Tom Holland
# 495                               Saoirse Ronan             Emma Watson
# 496                               George MacKay    Dean-Charles Chapman
# 497                           Michael B. Jordan              Jamie Foxx
# 498                               Alfre Woodard          Wendell Pierce
#
#        actor_3_name                                    genres  \
# 0    Leigh Whannell                           Horror Thriller
# 1     Emily Althaus                            Thriller Drama
# 2    Patrick Wilson                   Action Thriller Mystery
# 3       Billy Brown                     Thriller Action Crime
# 4     Shawn Ashmore                     Action Crime Thriller
# ..              ...                                       ...
# 494   Rashida Jones  Animation Action Adventure Comedy Family
# 495   Florence Pugh                      Romance Drama Family
# 496     Mark Strong                War History Thriller Drama
# 497     Brie Larson                       Drama Crime History
# 498     Aldis Hodge                                     Drama
#
#                  movie_title  \
# 0    insidious: the last key
# 1           the strange ones
# 2               the commuter
# 3                 proud mary
# 4           acts of violence
# ..                       ...
# 494        spies in disguise
# 495             little women
# 496                     1917
# 497               just mercy
# 498                 clemency
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3    Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 494  Will Smith Tom Holland Rashida Jones Nick Brun...
# 495  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 496  George MacKay Dean-Charles Chapman Mark Strong...
# 497  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 498  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [499 rows x 7 columns]

# %%
old_df = pd.read_csv(r"C:\Users\Asus\Downloads\netflix project\new_data.csv")
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5359       Keith Stanfield                   Romance Comedy
# 5360     Jean Louisa Kelly                          Romance
# 5361        Tiitus Rantala                   Romance Comedy
# 5362           Gina Holden       Crime Comedy Action Family
# 5363        Akshaye Khanna             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5359  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
final_df = pd.concat([old_df, my_df], ignore_index=True, sort=False)
final_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5858  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5859            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5860              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5861   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5862         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5858         Rashida Jones  Animation Action Adventure Comedy Family
# 5859         Florence Pugh                      Romance Drama Family
# 5860           Mark Strong                War History Thriller Drama
# 5861           Brie Larson                       Drama Crime History
# 5862           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5858                                  spies in disguise
# 5859                                       little women
# 5860                                               1917
# 5861                                         just mercy
# 5862                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5858  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5859  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5860  George MacKay Dean-Charles Chapman Mark Strong...
# 5861  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5862  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5863 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.to_csv(r'C:\Users\Asus\Downloads\netflix project\final_data.csv', index=False)
